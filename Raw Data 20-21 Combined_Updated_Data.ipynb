# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2 
import io

# %%
VAERS_DATA_21_df = pd.read_csv('Resources/Updated_Data/2021VAERSDATA.csv')
# Out:
# /Users/rimamehra/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (7,12,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
VAERS_DATA_21_df.head()
# Out:
#    VAERS_ID RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916600   1/1/21    TX     33.0     33.0      NaN   F      NaN
# 1    916601   1/1/21    CA     73.0     73.0      NaN   F      NaN
# 2    916602   1/1/21    WA     23.0     23.0      NaN   F      NaN
# 3    916603   1/1/21    WA     58.0     58.0      NaN   F      NaN
# 4    916604   1/1/21    TX     47.0     47.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Right side of epiglottis swelled up and hinder...  NaN  ...
# 1  Approximately 30 min post vaccination administ...  NaN  ...
# 2  About 15 minutes after receiving the vaccine, ...  NaN  ...
# 3  extreme fatigue, dizziness,. could not lift my...  NaN  ...
# 4  Injection site swelling, redness, warm to the ...  NaN  ...
#
#                                              CUR_ILL  \
# 0                                               None
# 1  Patient residing at nursing facility. See pati...
# ...

# %%
VAERS_DATA_20_df = pd.read_csv('Resources/Updated_Data/2020VAERSDATA.csv') 
VAERS_DATA_20_df.head()
# Out:
#    VAERS_ID RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    855017   1/1/20    HI     55.0     55.0      NaN   F      NaN
# 1    855018   1/1/20    WI     68.0     68.0      NaN   F      NaN
# 2    855019   1/1/20   NaN     50.0     50.0      NaN   F      NaN
# 3    855020   1/1/20    TX     67.0     67.0      NaN   F      NaN
# 4    855021   1/1/20   NaN     73.0     73.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 0  Symptoms occurred almost immediately- aching j...  NaN  ...    None
# 1  Extreme pain, muscle weakness in right arm so ...  NaN  ...    None
# 2            SORENESS IN THE AREA.  ITCHING AND RASH  NaN  ...     NaN
# 3  sore arm,  fever 101 , chills, and aching musc...  NaN  ...    none
# 4  Patient presented to Clinic today 1/1/2020. Sh...  NaN  ...     NaN
#
#                               HISTORY PRIOR_VAX SPLTTYPE  FORM_VERS  \
# ...

# %%
VAERS_DATA_ALL_df = VAERS_DATA_21_df.append(VAERS_DATA_20_df)

VAERS_DATA_ALL_df.head()
# Out:
#    VAERS_ID RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916600   1/1/21    TX     33.0     33.0      NaN   F      NaN
# 1    916601   1/1/21    CA     73.0     73.0      NaN   F      NaN
# 2    916602   1/1/21    WA     23.0     23.0      NaN   F      NaN
# 3    916603   1/1/21    WA     58.0     58.0      NaN   F      NaN
# 4    916604   1/1/21    TX     47.0     47.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Right side of epiglottis swelled up and hinder...  NaN  ...
# 1  Approximately 30 min post vaccination administ...  NaN  ...
# 2  About 15 minutes after receiving the vaccine, ...  NaN  ...
# 3  extreme fatigue, dizziness,. could not lift my...  NaN  ...
# 4  Injection site swelling, redness, warm to the ...  NaN  ...
#
#                                              CUR_ILL  \
# 0                                               None
# 1  Patient residing at nursing facility. See pati...
# ...

# %%
len(VAERS_DATA_ALL_df.index)
# Out:
# 86611

# %%
VAERS_DATA_ALL_df.drop_duplicates(subset ="VAERS_ID",
                     keep = False, inplace = True)

# %%
len(VAERS_DATA_ALL_df.index)
# Out:
# 86611

# %%
VAERS_DATA_ALL_df['DIED']=VAERS_DATA_ALL_df['DIED'].fillna(0)

# %%
len(VAERS_DATA_ALL_df.loc[VAERS_DATA_ALL_df['DIED'] == 'Y'])
# Out:
# 2315

# %%
 
engine = create_engine('postgresql://postgres:UTB00tcamp@team-11.ch3wmigorcf0.us-east-2.rds.amazonaws.com:5432/postgres', pool_recycle=3600)

VAERS_DATA_ALL_df.head(0).to_sql('vaersdata_raw', engine, if_exists='replace',index=False) #drops old table and creates new empty table

conn = engine.raw_connection()
cur = conn.cursor()
output = io.StringIO()
VAERS_DATA_ALL_df.to_csv(output, sep='\t', header=False, index=False)
output.seek(0)
contents = output.getvalue()
cur.copy_from(output, 'vaersdata_raw', null="") # null values become ''
conn.commit()

# %%
VAERS_SYMPT_21_df = pd.read_csv('Resources/Updated_Data/2021VAERSSYMPTOMS.csv') 
VAERS_SYMPT_21_df.head()
# Out:
#    VAERS_ID                 SYMPTOM1  SYMPTOMVERSION1  \
# 0    916600                Dysphagia             23.1
# 1    916601                  Anxiety             23.1
# 2    916602         Chest discomfort             23.1
# 3    916603                Dizziness             23.1
# 4    916604  Injection site erythema             23.1
#
#                   SYMPTOM2  SYMPTOMVERSION2                 SYMPTOM3  \
# 0             Epiglottitis             23.1                      NaN
# 1                 Dyspnoea             23.1                      NaN
# 2                Dysphagia             23.1        Pain in extremity
# 3                  Fatigue             23.1       Mobility decreased
# 4  Injection site pruritus             23.1  Injection site swelling
#
#    SYMPTOMVERSION3               SYMPTOM4  SYMPTOMVERSION4 SYMPTOM5  \
# 0              NaN                    NaN              NaN      NaN
# 1              NaN                    NaN              NaN      NaN
# ...

# %%
VAERS_SYMPT_20_df = pd.read_csv('Resources/Updated_Data/2020VAERSSYMPTOMS.csv') 
VAERS_SYMPT_20_df.head()
# Out:
#    VAERS_ID           SYMPTOM1  SYMPTOMVERSION1                SYMPTOM2  \
# 0    855017         Arthralgia             22.1                  Chills
# 1    855018             Chills             22.1                 Fatigue
# 2    855018  Muscular weakness             22.1       Pain in extremity
# 3    855019               Pain             22.1                Pruritus
# 4    855020             Chills             22.1  Influenza like illness
#
#    SYMPTOMVERSION2             SYMPTOM3  SYMPTOMVERSION3           SYMPTOM4  \
# 0             22.1  Injection site pain             22.1            Pyrexia
# 1             22.1         Hypertension             22.1      Hypoaesthesia
# 2             22.1              Pyrexia             22.1             Tremor
# 3             22.1                 Rash             22.1                NaN
# 4             22.1              Myalgia             22.1  Pain in extremity
#
#    SYMPTOMVERSION4                          SYMPTOM5  SYMPTOMVERSION5
# ...

# %%
VAERS_SYMPT_ALL_df = VAERS_SYMPT_21_df.append(VAERS_SYMPT_20_df)

VAERS_SYMPT_ALL_df.head()
# Out:
#    VAERS_ID                 SYMPTOM1  SYMPTOMVERSION1  \
# 0    916600                Dysphagia             23.1
# 1    916601                  Anxiety             23.1
# 2    916602         Chest discomfort             23.1
# 3    916603                Dizziness             23.1
# 4    916604  Injection site erythema             23.1
#
#                   SYMPTOM2  SYMPTOMVERSION2                 SYMPTOM3  \
# 0             Epiglottitis             23.1                      NaN
# 1                 Dyspnoea             23.1                      NaN
# 2                Dysphagia             23.1        Pain in extremity
# 3                  Fatigue             23.1       Mobility decreased
# 4  Injection site pruritus             23.1  Injection site swelling
#
#    SYMPTOMVERSION3               SYMPTOM4  SYMPTOMVERSION4 SYMPTOM5  \
# 0              NaN                    NaN              NaN      NaN
# 1              NaN                    NaN              NaN      NaN
# ...

# %%
len(VAERS_SYMPT_ALL_df.index)
# Out:
# 113487

# %%
# Faster Code to write to SQL database. Here writing the symtoms table.

engine = create_engine('postgresql://postgres:UTB00tcamp@team-11.ch3wmigorcf0.us-east-2.rds.amazonaws.com:5432/postgres', pool_recycle=3600)

VAERS_SYMPT_ALL_df.head(0).to_sql('vaerssymptom_raw', engine, if_exists='replace',index=False) #drops old table and creates new empty table

conn = engine.raw_connection()
cur = conn.cursor()
output = io.StringIO()
VAERS_SYMPT_ALL_df.to_csv(output, sep='\t', header=False, index=False)
output.seek(0)
contents = output.getvalue()
cur.copy_from(output, 'vaerssymptom_raw', null="") # null values become ''
conn.commit()

# %%
VAERS_VAX_21_df = pd.read_csv('Resources/Updated_Data/2021VAERSVAX.csv') 
VAERS_VAX_21_df.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    916600  COVID19          MODERNA  037K20A               1        IM
# 1    916601  COVID19          MODERNA  025L20A               1        IM
# 2    916602  COVID19  PFIZER\BIONTECH   EL1284               1        IM
# 3    916603  COVID19          MODERNA  unknown             UNK       NaN
# 4    916604  COVID19          MODERNA      NaN               1        IM
#
#   VAX_SITE                             VAX_NAME
# 0       LA          COVID19 (COVID19 (MODERNA))
# 1       RA          COVID19 (COVID19 (MODERNA))
# 2       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3      NaN          COVID19 (COVID19 (MODERNA))
# 4       LA          COVID19 (COVID19 (MODERNA))

# %%
len(VAERS_VAX_21_df.index)
# Out:
# 40937

# %%
VAERS_VAX_20_df = pd.read_csv('Resources/Updated_Data/2020VAERSVAX.csv') 
VAERS_VAX_20_df.head()
# Out:
#    VAERS_ID VAX_TYPE                     VAX_MANU VAX_LOT VAX_DOSE_SERIES  \
# 0    855017   VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN               2
# 1    855018      UNK         UNKNOWN MANUFACTURER     NaN               1
# 2    855019   VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN             UNK
# 3    855020   VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN             UNK
# 4    855021   VARZOS  GLAXOSMITHKLINE BIOLOGICALS     NaN               2
#
#   VAX_ROUTE VAX_SITE                       VAX_NAME
# 0       SYR       LA              ZOSTER (SHINGRIX)
# 1        IM       RA  VACCINE NOT SPECIFIED (OTHER)
# 2       NaN      NaN              ZOSTER (SHINGRIX)
# 3        IM       LA              ZOSTER (SHINGRIX)
# 4        IM       RA              ZOSTER (SHINGRIX)

# %%
len(VAERS_VAX_20_df.index)
# Out:
# 55640

# %%
VAERS_VAX_ALL_df = VAERS_VAX_21_df.append(VAERS_VAX_20_df)

VAERS_VAX_ALL_df.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    916600  COVID19          MODERNA  037K20A               1        IM
# 1    916601  COVID19          MODERNA  025L20A               1        IM
# 2    916602  COVID19  PFIZER\BIONTECH   EL1284               1        IM
# 3    916603  COVID19          MODERNA  unknown             UNK       NaN
# 4    916604  COVID19          MODERNA      NaN               1        IM
#
#   VAX_SITE                             VAX_NAME
# 0       LA          COVID19 (COVID19 (MODERNA))
# 1       RA          COVID19 (COVID19 (MODERNA))
# 2       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3      NaN          COVID19 (COVID19 (MODERNA))
# 4       LA          COVID19 (COVID19 (MODERNA))

# %%
len(VAERS_VAX_ALL_df.index)
# Out:
# 96577

# %%
# Writing the Vax table to the Database.

engine = create_engine('postgresql://postgres:UTB00tcamp@team-11.ch3wmigorcf0.us-east-2.rds.amazonaws.com:5432/postgres', pool_recycle=3600)

VAERS_VAX_ALL_df.head(0).to_sql('vaersvax_raw', engine, if_exists='replace',index=False) #drops old table and creates new empty table

conn = engine.raw_connection()
cur = conn.cursor()
output = io.StringIO()
VAERS_VAX_ALL_df.to_csv(output, sep='\t', header=False, index=False)
output.seek(0)
contents = output.getvalue()
cur.copy_from(output, 'vaersvax_raw', null="") # null values become ''
conn.commit()

# %%
# result = pd.merge(VAERS_DATA_ALL_df, VAERS_VAX_ALL_df, on="VAERS_ID")

# %%
# result.head()

# %%
# len(result.index)

# %%
# len(result.loc[result['VAX_TYPE'] == 'COVID19'])

# %%
# Once i added this step to drop the duplicates my previous death count of 2190 dropped to 2041.
# Before we updated our data the death count was about 1421. Need a check and confirmation on this. 

# result.drop_duplicates(subset ="VAERS_ID",
#                      keep = False, inplace = True)

# %%
# result_COVID = result[result.VAX_TYPE == "COVID19"]

# %%
# len(result_COVID.index)

# %%
# len(result_COVID.loc[result_COVID['DIED'] == 'Y'])
